# %%
import pyvista as pv
import pandas as pd
import seaborn as sns

# %%
mesh = pv.read(r"D:\99_Tests\point_cloud_offset_EPSG32629 - classified - Cloud.vtk")
# Out:
# ERROR:root:Unsupported point attribute type: point_data for file: D:\99_Tests\point_cloud_offset_EPSG32629 - classified - Cloud.vtk

# %%
mesh.
# Out:
# PolyData (0x1f0d40c0be0)
#   N Cells:    1037725
#   N Points:   1037725
#   N Strips:   0
#   X Bounds:   6.165e+02, 6.291e+02
#   Y Bounds:   2.254e+02, 2.422e+02
#   Z Bounds:   -8.752e+02, -8.693e+02
#   N Arrays:   4

# %%
plotter = pv.Plotter()
plotter.add_mesh(mesh, render_points_as_spheres=True, point_size=5, sclalar = 'Classification')
#plotter.enable_eye_dome_lighting()
plotter.add_legend_scale()
plotter.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 plotter = pv.Plotter()
# ----> 2 plotter.add_mesh(mesh, render_points_as_spheres=True, point_size=5, sclalar = 'Classification')
#       3 #plotter.enable_eye_dome_lighting()
#       4 plotter.add_legend_scale()
#
# File ~\AppData\Local\miniforge3\envs\reprojection_env\Lib\site-packages\pyvista\_deprecate_positional_args.py:245, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     241             warnings.warn(msg, PyVistaDeprecationWarning, stacklevel=stack_level)
#     243         warn_positional_args()
# --> 245 return f(*args, **kwargs)
#
# ...
